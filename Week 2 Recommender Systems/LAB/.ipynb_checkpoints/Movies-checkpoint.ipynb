# %% [markdown]
# # Public Media
# ## Hans Franke

# %% [markdown]
# ### Lab assignment 02
#
# For this assignment you can use the movies dataset (movies) or the books dataset. When using the movies dataset combine the movies_metadata.csv and ratings_small.cvs or ratings.csv in Pandas. Create recommendations based on these reviews. So people who reviewed A also reviewed B. Best is to downsize the dataset in order to test the code before it runs for a while.
#
# Also, change the combinations from 2 to 3. Explore some books/movies.

# %%
# import libraries
import pandas as pd

# load the dataset
movies_metadata = pd.read_csv('data/movies/movies_metadata.csv', low_memory=False)
ratings = pd.read_csv('data/movies/ratings.csv', low_memory=False)

# %%
movies_metadata.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
movies_metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26024289 entries, 0 to 26024288
# Data columns (total 4 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   userId     int64
#  1   movieId    int64
#  2   rating     float64
#  3   timestamp  int64
# dtypes: float64(1), int64(3)
# memory usage: 794.2 MB

# %%
movies_metadata.id
# Out:
# 0           862
# 1          8844
# 2         15602
# 3         31357
# 4         11862
#           ...
# 45461    439050
# 45462    111109
# 45463     67758
# 45464    227506
# 45465    461257
# Name: id, Length: 45466, dtype: object

# %%
#convert id to int64
#remove bad indexes (shit!!)
movies_metadata = movies_metadata.drop([19730, 29503, 35587])
movies_metadata['id'] = movies_metadata['id'].astype("int")

#Combine the datasets

merged_movies = movies_metadata.merge(ratings, left_on='id', right_on='movieId')
merged_movies.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 2  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 3  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 4  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 2  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 3  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 4  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
#
#                                homepage   id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story  862  tt0114709                en
# ...

# %%
from itertools import permutations

# create a function that makes combinations of the books that a user (x) reviewed
def create_combinations(x):
    combinations = pd.DataFrame(list(permutations(x.values, 2)), columns=['item_a', 'item_b'])
    return combinations

# %%
#look for user reviews
avg_user = merged_movies.groupby(['userId']).size().reset_index(name='counts')
avg_user = avg_user.set_index('userId')
avg_user.reset_index().sort_values('counts', ascending=False)
# Out:
#         userId  counts
# 44975    45811    3594
# 8509      8659    3024
# 176472  179792    2578
# 105716  107720    2103
# 265168  270123    2040
# ...        ...     ...
# 117770  120015       1
# 256367  261161       1
# 210886  214825       1
# 117779  120024       1
# 122478  124818       1
#
# [265917 rows x 2 columns]

# %%
#Smaller selection
avg_user = avg_user[avg_user['counts'] > 200]
users_index = avg_user.index

smaller_selection = merged_movies.iloc[users_index]
smaller_selection.head()
# Out:
#      adult                              belongs_to_collection    budget  \
# 24   False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 46   False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 120  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 132  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 150  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
#
#                                                 genres  \
# 24   [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 46   [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 120  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 132  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 150  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
#
#                                  homepage   id    imdb_id original_language  \
# 24   http://toystory.disney.com/toy-story  862  tt0114709                en
# ...

# %%
# use the create_combinations function

movie_combinations = smaller_selection.groupby('userId')['original_title'].apply(create_combinations)

movie_combinations.head(4)
# Out:
#                               item_a                      item_b
# userId
# 1602   0                      Casino  La Cité des Enfants Perdus
#        1  La Cité des Enfants Perdus                      Casino
# 2361   0              Twelve Monkeys              Before Sunrise
#        1              Before Sunrise              Twelve Monkeys

# %%
# calculate the occurences of book a and book b

movie_combinations = movie_combinations.reset_index(drop=True)
combi_count = movie_combinations.groupby(['item_a', 'item_b']).size()
combi_count = combi_count.to_frame(name='size').reset_index()
combi_count.sort_values('size', ascending=False).head(5)
# Out:
#                  item_a              item_b  size
# 425  Once Were Warriors  Mr. Holland's Opus    19
# 370  Mr. Holland's Opus  Once Were Warriors    19
# 484           Star Wars  Once Were Warriors    16
# 429  Once Were Warriors           Star Wars    16
# 411  Once Were Warriors    Cutthroat Island    16

# %%
# search for a specific
combi_count[combi_count['item_a'] == 'Star Wars'].sort_values('size', ascending=False).head(10)
# Out:
#         item_a                         item_b  size
# 484  Star Wars             Once Were Warriors    16
# 475  Star Wars                     Four Rooms    10
# 471  Star Wars                         Casino     8
# 474  Star Wars               Don Juan DeMarco     4
# 482  Star Wars             Mr. Holland's Opus     3
# 490  Star Wars         Trois couleurs : Rouge     3
# 480  Star Wars     La Cité des Enfants Perdus     3
# 468  Star Wars                 Before Sunrise     2
# 478  Star Wars     Interview with the Vampire     2
# 487  Star Wars  The Bridges of Madison County     2
